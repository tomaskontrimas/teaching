# %% [markdown]
# # Exercise: Context managers
#
# ## About
# This excersise trains you about Python context managers.
#
# Context managers in Python allow you to allocate and release resources precisely when you want to. The most widely used example of context managers is the with statement.
#
# Python implements context managers via two magic class methods:
#
# ```python
# __enter__(self)
# __exit__(self, type, value, traceback)
# ```
#
# ## Tasks
#
# 1. Write a `Timer` context manager class which times the code execution within the `with` block.
#
#   [Learing objectives: context manager]
#
# ### Useful function
# `time.time() → float`
# > Return the time in seconds since the epoch as a floating point number. The specific date of the epoch and the handling of leap seconds is platform dependent. On Windows and most Unix systems, the epoch is January 1, 1970, 00:00:00 (UTC) and leap seconds are not counted towards the time in seconds since the epoch. This is commonly referred to as Unix time. To find out what the epoch is on a given platform, look at gmtime(0).

# %%
from time import time, sleep


class Timer(object):
    pass

# %%
with Timer():
    sleep(2)
# Out:
# Time elapsed: 2.00s
