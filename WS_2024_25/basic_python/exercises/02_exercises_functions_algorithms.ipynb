# %% [markdown]
# # Introduction
#
# This notebook contains tasks that aim to help you to get familiar with writing and using functions. In addition, you will learn how to translate mathematical algorithms into code.

# %% [markdown]
# # Task: Vectors
#
# * Write functions that implement vector addition, scalar product (https://en.wikipedia.org/wiki/Dot_product), and vector product (https://en.wikipedia.org/wiki/Cross_product).
#
# * Write a subtraction function that re-uses the addition function in a clever way
#
# * Bonus tasks:
#     * Take care of checking the input parameters! (Right type, length, etc.)
#     * Write an extra function for checking the input parameters that you can re-use in all vector functions

# %%
def vector_add(vec_1, vec_2):
    # pass just does nothing. 
    # it is used as a placeholder for code to be implemented
    # without pass, this function without content would cause an Error
    pass

def scalar_product(vec_1, vec_2):
    pass

def vector_product(vec_1, vec_2):
    pass

# %% [markdown]
# # Task: Designing a math algorithm
# 1. Implement a function that prints out the first 'n' elements of the Fibonacci sequence
# 2. Implement a function that calculates $e$ (Euler's number) up to a given precision (hint: look up the series that defines $e$)
# 3. Implement a function that calculates $\pi$ up to a given precision
# 4. Bonus: calculate $\pi$ via geometry
#
# Precision could mean e.g. that the difference between one iteration and the next is smaller than the given precision.

# %% [markdown]
# Some advice for designing an algorithm:
# * write down in simple text the steps needed for the calculation
# * if helpful, make a sketch (eg. when solving geometry problems like the calculation of pi)
# * think about which steps of your "text" algorithm represents loops, conditions, variables...

# %%
def fibonacci(n):
    # print out the first n fibonacci numbers
    pass # currently, this function does nothing

def calc_e(precision):
    # calculate e up to a given precision
    pass

def calc_pi(precision):
    # calculate pi up to a given precision
    pass

# %% [markdown]
# ## Help: Fibonacci numbers
# * $n_0=0$
# * $n_1=1$
# * $n_2 = n_0 + n_1 = 1$
# * $n_3 = n_1 + n_2 = 2$
# * $n_4 = n_2 + n_3 = 3$
# * $n_5 = n_3 + n_4 = 5$, ...
# * $n_{i} = ???$ -> Implement the algorithm!
#
# Print all numbers from $n_0$ up to $n_{10}$

# %% [markdown]
# ### with a loop

# %%
def fibo(n, print_this=True):
    # start values
    n_im2 = 0
    n_im1 = 1
    result = []
    for i in range(n):
        if print_this:
            print(f"n_{i}={n_im2}")
        ''' Implement your code here '''
        # ...
    return result

# %%
fib_nums = fibo(11)
# Out:
# n_0=0
# n_1=1
# n_2=1
# n_3=2
# n_4=3
# n_5=5
# n_6=8
# n_7=13
# n_8=21
# n_9=34
# n_10=55

# %% [markdown]
# ### Bonus: with a recursive function

# %%
def recur_fibo(n):
    if ... :# termination
        ''' Implement your code here '''
        # ...
    else:
        # recursive function calls
        ''' Implement your code here '''
        # ...

# %%
num = 11
for i in range(num):
    print(f"n_{i}={recur_fibo(i)}")
# Out:
# Fibonacci sequence:
# n_0=0
# n_1=1
# n_2=1
# n_3=2
# n_4=3
# n_5=5
# n_6=8
# n_7=13
# n_8=21
# n_9=34
# n_10=55

# %% [markdown]
# # Advanced Task: Sorting algorithms
#
# Write a function that returns a sorted list.
# Try to come up with a solution yourself, then look up advanced sorting algorithms and try to implement them.

# %%
def sorter(a_list):
    # write an algorithm that sorts the list
    sorted_list = []
    return sorted_list
